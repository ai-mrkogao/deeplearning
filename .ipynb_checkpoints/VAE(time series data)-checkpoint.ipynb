# %%
import tensorflow as tf
import numpy as np
import pandas as pd

import os
import glob
import re

import sys
sys.path.append("./src/") 

import mnist_data
import plot_utils
import gzip

# %% [markdown]
# ### Read time series data

# %%
def readData(filelists):

    try:
        savedir = './data'

        mergeddata = []
        for file in filelists:
            filename = file
            stocksavedir = savedir+'/'+filename

            np_data = []
            for _inputname in ['np_train','np_test']:
                with gzip.open( stocksavedir+'/'+_inputname+'.npy.gz', 'r') as infile:
                    np_data.append(np.load(infile))

            df_data = []
            for _inputname in ['df_train','df_test']:
                df_data.append(pd.read_pickle(stocksavedir+'/'+_inputname+'.pkl'))
            
            mergeddata.append([np_data[0],np_data[1],df_data[0],df_data[1]])

        return mergeddata

    except Exception as e:
        print(e)

# %%
filelists = ['DJI']
mergeddata = readData(filelists)
np_train = mergeddata[0][0]
print(np_train.shape)
np_test = mergeddata[0][1]
print(np_test.shape)
df_train = mergeddata[0][2]
# print(df_train.head())
print(df_train.shape)
# df_train['signal_5ma'][:10]
df_train['id'] = 0
df_train.loc[(df_train['signal_5ma'] == 9) , ['id']] = 1
df_train.loc[(df_train['signal_5ma'] == 8) , ['id']] = 2
df_train.loc[(df_train['signal_5ma'] == -9) , ['id']] = 3
df_train.loc[(df_train['signal_5ma'] == 0) , ['id']] = 0
# Out:
# (2079, 4323)
# (891, 4323)
# (2079, 30)

# %% [markdown]
# ### build variational autoencoder

# %%
class vae:
    def __init__(self,session,learning_rate,dense_layers,dense_funcs,dim_z,dim_out):

        self.session = session
        self.dim_in = dim_out
        self.dim_out = dim_out
        self.dim_z = dim_z
        
        self.lrate = learning_rate
        self.dense_layers = dense_layers
        self.dense_funcs = dense_funcs
        
        self.model_name = 'vae'
        self.logs_dir = './model'
        self._build_network()
        
    def _build_network(self):
        
        self.x_hat = tf.placeholder(tf.float32, shape=[None, self.dim_in], name='input_denoising')
        self.x = tf.placeholder(tf.float32, shape=[None, self.dim_out], name='target')

        # dropout
        self.keep_prob = tf.placeholder(tf.float32, name='keep_prob')

        # input for PMLR
        self.z_in = tf.placeholder(tf.float32, shape=[None, self.dim_z], name='latent_variable')
        
        self.encoder_dense_layers = self.dense_layers+[self.dim_z]
        self.encoder_dense_funcs = self.dense_funcs
        print("encoder_dense_layers {}".format(self.encoder_dense_layers))
        
        self.mu,self.sigma = self.encoder(self.x_hat,self.encoder_dense_layers,self.encoder_dense_funcs,self.keep_prob)
        
        print("mu:{} sigma:{}".format(self.mu.shape,self.sigma.shape))
        # sampling by re-parameterization technique
        self.z = self.mu + self.sigma * tf.random_normal(tf.shape(self.mu), 0, 1, dtype=tf.float32)
        print("encoder output z:{}".format(self.z.shape))

        self.decoder_dense_layers = self.dense_layers[::-1]+[self.dim_out]
        self.decoder_activ = self.encoder_dense_funcs[::-1]
        print("decoder_dense_layers {}".format(self.decoder_dense_layers))
        
        # decoding
        self.y = self.decoder(self.z, self.decoder_dense_layers,self.decoder_activ, self.keep_prob)
        self.y = tf.clip_by_value(self.y, 1e-8, 1 - 1e-8)
        print("decoder output y:{}".format(self.y.shape))
        # loss
        self.marginal_likelihood = tf.reduce_sum(self.x * tf.log(self.y) + (1 - self.x) * tf.log(1 - self.y), 1)
        self.KL_divergence = 0.5 * tf.reduce_sum(tf.square(self.mu) + tf.square(self.sigma) - tf.log(1e-8 + tf.square(self.sigma)) - 1, 1)

        self.marginal_likelihood = tf.reduce_mean(self.marginal_likelihood)
        self.KL_divergence = tf.reduce_mean(self.KL_divergence)

        self.ELBO = self.marginal_likelihood - self.KL_divergence

        self.loss = -self.ELBO
        
        self.decoded = self.sample_decoder(self.z_in, self.dim_out)
        
        self.train_op = tf.train.AdamOptimizer(self.lrate).minimize(self.loss)
        self.neg_marginal_likelihood = -1*self.marginal_likelihood
        
        self.global_step = tf.Variable(0, name='global_step',trainable=False)
        self.saver = tf.train.Saver(max_to_keep=1)
        
        
    def save(self, step):
        model_name = self.model_name + ".model"
                
        model_logs_dir = self.logs_dir
        if not os.path.exists(model_logs_dir):
            os.makedirs(model_logs_dir)
            
        self.saver.save(
            self.session,
            os.path.join(model_logs_dir, model_name),
            global_step=step
        )
    def load(self):
    
        ckpt = tf.train.get_checkpoint_state(self.logs_dir)
        
        if ckpt and ckpt.model_checkpoint_path:
            ckpt_name = os.path.basename(ckpt.model_checkpoint_path)
            # print('ckpt_name {} self.logs_dir {}'.format(ckpt_name,self.logs_dir))
            self.saver.restore(self.session, os.path.join(self.logs_dir, ckpt_name))
            counter = int(next(re.finditer("(\d+)(?!.*\d)", ckpt_name)).group(0))
            print(" [*] Success to read {}".format(ckpt_name))
            return True, counter

        else:
            print(" [*] Failed to find a " +self.logs_dir+ " checkpoint")
            return False, 0
    
    def sample_decoder(self,z, dim_img):

        # decoding
        y = self.decoder(z, self.decoder_dense_layers,self.decoder_activ, 1.0, reuse=True)
        return y
    
    def encoder(self,x, dense_layers,dense_func,keep_prob):
        with tf.variable_scope("encoder"):

            # initializers
            w_init = tf.contrib.layers.variance_scaling_initializer()
            b_init = tf.constant_initializer(0.)

            # dense layers
            dense_input_shape = x.get_shape()[1]
            dense_input = x
            for _i,_n_hidden in enumerate(dense_layers[:-1]):
                net_w = tf.get_variable('w'+str(_i),[dense_input_shape,_n_hidden],initializer=w_init)
                net_b = tf.get_variable('b'+str(_i),[_n_hidden],initializer = b_init)
                net_h = tf.matmul(dense_input,net_w) + net_b 
                if dense_func[_i] == 'elu':
                    actfunc = tf.nn.elu
                elif dense_func[_i] == 'tanh':
                    actfunc = tf.nn.tanh
                net_h = actfunc(net_h)
                net_h = tf.nn.dropout(net_h,keep_prob)
                dense_input_shape = net_h.get_shape()[1]
                dense_input = net_h

            # final output
            final_w = tf.get_variable("w_final",[dense_input.get_shape()[1],dense_layers[-1]*2],initializer = w_init)
            final_b = tf.get_variable("b_final",[dense_layers[-1]*2],initializer=b_init)
            gaussian_params = tf.matmul(dense_input,final_w) + final_b

            mean = gaussian_params[:,:dense_layers[-1]]
            stddev = 1e-6 +tf.nn.softplus(gaussian_params[:,dense_layers[-1]:])
            print("gaussian encoder mean:{} ".format(mean.shape))


        return mean, stddev
    
    # Bernoulli as decoder
    # bernoulli_decoder(z, [500,500,784],['tanh','elu'], keep_prob, reuse=False)
    def decoder(self,z, dense_layers,dense_func, keep_prob, reuse=False):

        with tf.variable_scope("decoder", reuse=reuse):
            # initializers
            w_init = tf.contrib.layers.variance_scaling_initializer()
            b_init = tf.constant_initializer(0.)

            # dense layers
            dense_input_shape = z.get_shape()[1]
            dense_input = z
            for _i,_n_hidden in enumerate(dense_layers[:-1]):
                net_w = tf.get_variable('w'+str(_i),[dense_input_shape,_n_hidden],initializer=w_init)
                net_b = tf.get_variable('b'+str(_i),[_n_hidden],initializer = b_init)
                net_h = tf.matmul(dense_input,net_w) + net_b 
                if dense_func[_i] == 'elu':
                    actfunc = tf.nn.elu
                elif dense_func[_i] == 'tanh':
                    actfunc = tf.nn.tanh
                net_h = actfunc(net_h)
                net_h = tf.nn.dropout(net_h,keep_prob)
                dense_input_shape = net_h.get_shape()[1]
                dense_input = net_h

            # final output
            final_w = tf.get_variable("w_final",[dense_input.get_shape()[1],dense_layers[-1]],initializer = w_init)
            final_b = tf.get_variable("b_final",[dense_layers[-1]],initializer=b_init)
            y = tf.sigmoid(tf.matmul(dense_input,final_w)+final_b)


        return y

# %%
with tf.Session() as sess:
        
    learning_rate= 0.0005
    dense_layers = [1500,700,300]
    dense_funcs = ['elu','elu','tanh']
    dim_z = 2#20 # latent vector size
    dim_out = np_train.shape[1]
    
    
    autoencoder = vae(sess,learning_rate,dense_layers,dense_funcs,dim_z,dim_out)
    sess.run(tf.global_variables_initializer(), feed_dict={autoencoder.keep_prob : 0.9})
    
    # train
    n_epochs = 200
    batch_size = 40
    n_samples = np_train.shape[0]
    total_batch = int(n_samples / batch_size)
    ADD_NOISE = True
    train_total_data = np_train
    
    for epoch in range(n_epochs):

        # Random shuffling
        np.random.shuffle(train_total_data)
        train_data_ = train_total_data

        # Loop over all batches
        for i in range(total_batch):
            # Compute the offset of the current minibatch in the data.
            offset = (i * batch_size) % (n_samples)
            batch_xs_input = train_data_[offset:(offset + batch_size), :]

            batch_xs_target = batch_xs_input
            
            
            # add salt & pepper noise
            if ADD_NOISE:
                batch_xs_input = batch_xs_input * np.random.randint(2, size=batch_xs_input.shape)
                batch_xs_input += np.random.randint(2, size=batch_xs_input.shape)
            
            _, tot_loss, loss_likelihood, loss_divergence = sess.run(
                (autoencoder.train_op, autoencoder.loss, autoencoder.neg_marginal_likelihood, autoencoder.KL_divergence),
                feed_dict={autoencoder.x_hat: batch_xs_input, autoencoder.x: batch_xs_target, autoencoder.keep_prob : 0.9})
            
            
#         print("epoch {}".format(epoch))
        # print cost every epoch
        print("epoch %d: L_tot %03.2f L_likelihood %03.2f L_divergence %03.2f" % (epoch, tot_loss, loss_likelihood, loss_divergence))

        
    autoencoder.save(1)
# Out:
# encoder_dense_layers [1500, 700, 300, 2]
# gaussian encoder mean:(?, 2)
# mu:(?, 2) sigma:(?, 2)
# encoder output z:(?, 2)
# decoder_dense_layers [300, 700, 1500, 4323]
# decoder output y:(?, 4323)
# epoch 0: L_tot 2867.42 L_likelihood 2857.96 L_divergence 9.45
# epoch 1: L_tot 2870.09 L_likelihood 2864.08 L_divergence 6.01
# epoch 2: L_tot 2855.02 L_likelihood 2849.36 L_divergence 5.67
# epoch 3: L_tot 2848.71 L_likelihood 2844.13 L_divergence 4.58
# epoch 4: L_tot 2828.04 L_likelihood 2824.32 L_divergence 3.72
# epoch 5: L_tot 2815.72 L_likelihood 2811.70 L_divergence 4.03
# epoch 6: L_tot 2772.65 L_likelihood 2768.78 L_divergence 3.87
# epoch 7: L_tot 2799.08 L_likelihood 2795.67 L_divergence 3.40
# epoch 8: L_tot 2814.77 L_likelihood 2811.07 L_divergence 3.70
# epoch 9: L_tot 2811.79 L_likelihood 2808.42 L_divergence 3.37
# epoch 10: L_tot 2818.30 L_likelihood 2814.59 L_divergence 3.71
# epoch 11: L_tot 2803.16 L_likelihood 2799.91 L_divergence 3.25
# epoch 12: L_tot 2822.19 L_likelihood 2818.75 L_divergence 3.44
# epoch 13: L_tot 2794.56 L_likelihood 2791.35 L_divergence 3.21
# epoch 14: L_tot 2781.69 L_likelihood 2778.14 L_divergence 3.55
# epoch 15: L_tot 2779.89 L_likelihood 2776.56 L_divergence 3.33
# epoch 16: L_tot 2796.49 L_likelihood 2793.44 L_divergence 3.05
# epoch 17: L_tot 2811.31 L_likelihood 2808.07 L_divergence 3.24
# epoch 18: L_tot 2783.29 L_likelihood 2779.88 L_divergence 3.41
# epoch 19: L_tot 2796.27 L_likelihood 2792.62 L_divergence 3.66
# epoch 20: L_tot 2806.40 L_likelihood 2803.43 L_divergence 2.97
# epoch 21: L_tot 2785.08 L_likelihood 2781.40 L_divergence 3.69
# epoch 22: L_tot 2802.40 L_likelihood 2799.43 L_divergence 2.96
# epoch 23: L_tot 2782.56 L_likelihood 2779.01 L_divergence 3.55
# epoch 24: L_tot 2790.09 L_likelihood 2787.13 L_divergence 2.96
# epoch 25: L_tot 2791.97 L_likelihood 2788.21 L_divergence 3.76
# epoch 26: L_tot 2784.26 L_likelihood 2781.14 L_divergence 3.11
# epoch 27: L_tot 2810.60 L_likelihood 2807.33 L_divergence 3.27
# epoch 28: L_tot 2770.74 L_likelihood 2767.44 L_divergence 3.31
# epoch 29: L_tot 2791.53 L_likelihood 2788.51 L_divergence 3.03
# epoch 30: L_tot 2820.01 L_likelihood 2817.51 L_divergence 2.50
# epoch 31: L_tot 2800.53 L_likelihood 2797.21 L_divergence 3.33
# epoch 32: L_tot 2804.32 L_likelihood 2801.50 L_divergence 2.82
# epoch 33: L_tot 2805.78 L_likelihood 2802.47 L_divergence 3.31
# epoch 34: L_tot 2807.41 L_likelihood 2804.99 L_divergence 2.43
# epoch 35: L_tot 2826.57 L_likelihood 2823.74 L_divergence 2.83
# epoch 36: L_tot 2767.00 L_likelihood 2764.21 L_divergence 2.79
# epoch 37: L_tot 2814.55 L_likelihood 2812.10 L_divergence 2.45
# epoch 38: L_tot 2798.16 L_likelihood 2795.33 L_divergence 2.82
# epoch 39: L_tot 2788.81 L_likelihood 2785.79 L_divergence 3.02
# epoch 40: L_tot 2782.86 L_likelihood 2779.89 L_divergence 2.97
# epoch 41: L_tot 2777.01 L_likelihood 2773.67 L_divergence 3.33
# epoch 42: L_tot 2797.54 L_likelihood 2794.63 L_divergence 2.91
# epoch 43: L_tot 2773.07 L_likelihood 2770.22 L_divergence 2.85
# epoch 44: L_tot 2815.82 L_likelihood 2812.68 L_divergence 3.15
# epoch 45: L_tot 2786.57 L_likelihood 2783.23 L_divergence 3.34
# epoch 46: L_tot 2797.22 L_likelihood 2794.27 L_divergence 2.96
# epoch 47: L_tot 2795.63 L_likelihood 2792.83 L_divergence 2.80
# epoch 48: L_tot 2791.44 L_likelihood 2788.26 L_divergence 3.19
# epoch 49: L_tot 2785.50 L_likelihood 2782.57 L_divergence 2.92
# epoch 50: L_tot 2806.14 L_likelihood 2803.18 L_divergence 2.95
# epoch 51: L_tot 2803.83 L_likelihood 2800.91 L_divergence 2.91
# epoch 52: L_tot 2756.72 L_likelihood 2753.68 L_divergence 3.04
# epoch 53: L_tot 2787.38 L_likelihood 2784.80 L_divergence 2.58
# epoch 54: L_tot 2786.82 L_likelihood 2784.11 L_divergence 2.71
# epoch 55: L_tot 2810.02 L_likelihood 2807.15 L_divergence 2.87
# epoch 56: L_tot 2821.47 L_likelihood 2818.88 L_divergence 2.59
# epoch 57: L_tot 2805.61 L_likelihood 2802.69 L_divergence 2.93
# epoch 58: L_tot 2790.50 L_likelihood 2788.16 L_divergence 2.34
# epoch 59: L_tot 2811.45 L_likelihood 2808.90 L_divergence 2.55
# epoch 60: L_tot 2757.29 L_likelihood 2753.97 L_divergence 3.32
# epoch 61: L_tot 2773.92 L_likelihood 2770.90 L_divergence 3.02
# epoch 62: L_tot 2797.77 L_likelihood 2794.82 L_divergence 2.95
# epoch 63: L_tot 2760.00 L_likelihood 2757.80 L_divergence 2.21
# epoch 64: L_tot 2812.20 L_likelihood 2808.99 L_divergence 3.21
# epoch 65: L_tot 2792.50 L_likelihood 2789.40 L_divergence 3.10
# epoch 66: L_tot 2759.02 L_likelihood 2756.36 L_divergence 2.66
# epoch 67: L_tot 2780.68 L_likelihood 2778.16 L_divergence 2.52
# epoch 68: L_tot 2787.64 L_likelihood 2784.91 L_divergence 2.73
# epoch 69: L_tot 2761.85 L_likelihood 2758.79 L_divergence 3.06
# epoch 70: L_tot 2775.37 L_likelihood 2772.32 L_divergence 3.06
# epoch 71: L_tot 2802.18 L_likelihood 2799.28 L_divergence 2.90
# epoch 72: L_tot 2760.01 L_likelihood 2757.48 L_divergence 2.54
# epoch 73: L_tot 2793.96 L_likelihood 2791.24 L_divergence 2.72
# epoch 74: L_tot 2803.32 L_likelihood 2800.78 L_divergence 2.53
# epoch 75: L_tot 2763.84 L_likelihood 2761.33 L_divergence 2.51
# epoch 76: L_tot 2771.57 L_likelihood 2768.97 L_divergence 2.60
# epoch 77: L_tot 2771.80 L_likelihood 2768.62 L_divergence 3.19
# epoch 78: L_tot 2788.13 L_likelihood 2785.00 L_divergence 3.13
# epoch 79: L_tot 2779.70 L_likelihood 2776.86 L_divergence 2.84
# epoch 80: L_tot 2788.88 L_likelihood 2786.29 L_divergence 2.59
# epoch 81: L_tot 2786.78 L_likelihood 2783.89 L_divergence 2.89
# epoch 82: L_tot 2781.93 L_likelihood 2778.81 L_divergence 3.12
# epoch 83: L_tot 2786.57 L_likelihood 2783.55 L_divergence 3.02
# epoch 84: L_tot 2793.75 L_likelihood 2791.26 L_divergence 2.49
# epoch 85: L_tot 2805.32 L_likelihood 2801.96 L_divergence 3.35
# epoch 86: L_tot 2786.94 L_likelihood 2784.06 L_divergence 2.88
# epoch 87: L_tot 2809.77 L_likelihood 2807.04 L_divergence 2.73
# epoch 88: L_tot 2778.78 L_likelihood 2775.60 L_divergence 3.18
# epoch 89: L_tot 2804.92 L_likelihood 2801.67 L_divergence 3.25
# epoch 90: L_tot 2788.06 L_likelihood 2785.05 L_divergence 3.01
# epoch 91: L_tot 2819.70 L_likelihood 2817.18 L_divergence 2.52
# epoch 92: L_tot 2789.15 L_likelihood 2786.03 L_divergence 3.13
# epoch 93: L_tot 2792.30 L_likelihood 2788.65 L_divergence 3.65
# epoch 94: L_tot 2773.61 L_likelihood 2770.71 L_divergence 2.90
# epoch 95: L_tot 2776.28 L_likelihood 2773.00 L_divergence 3.27
# epoch 96: L_tot 2768.29 L_likelihood 2765.33 L_divergence 2.95
# epoch 97: L_tot 2792.52 L_likelihood 2788.94 L_divergence 3.58
# epoch 98: L_tot 2787.80 L_likelihood 2784.17 L_divergence 3.63
# epoch 99: L_tot 2791.65 L_likelihood 2788.38 L_divergence 3.27
# epoch 100: L_tot 2798.19 L_likelihood 2794.52 L_divergence 3.67
# epoch 101: L_tot 2792.12 L_likelihood 2788.78 L_divergence 3.34
# epoch 102: L_tot 2814.70 L_likelihood 2811.25 L_divergence 3.45
# epoch 103: L_tot 2776.68 L_likelihood 2773.56 L_divergence 3.12
# epoch 104: L_tot 2795.89 L_likelihood 2792.75 L_divergence 3.13
# epoch 105: L_tot 2780.76 L_likelihood 2777.88 L_divergence 2.88
# epoch 106: L_tot 2795.94 L_likelihood 2793.12 L_divergence 2.82
# epoch 107: L_tot 2796.48 L_likelihood 2793.42 L_divergence 3.06
# epoch 108: L_tot 2776.66 L_likelihood 2773.76 L_divergence 2.90
# epoch 109: L_tot 2798.77 L_likelihood 2795.85 L_divergence 2.92
# epoch 110: L_tot 2790.85 L_likelihood 2787.87 L_divergence 2.98
# epoch 111: L_tot 2775.73 L_likelihood 2772.67 L_divergence 3.06
# epoch 112: L_tot 2786.06 L_likelihood 2782.94 L_divergence 3.12
# epoch 113: L_tot 2772.17 L_likelihood 2769.31 L_divergence 2.86
# epoch 114: L_tot 2789.33 L_likelihood 2785.88 L_divergence 3.45
# epoch 115: L_tot 2788.64 L_likelihood 2785.39 L_divergence 3.25
# epoch 116: L_tot 2770.95 L_likelihood 2768.10 L_divergence 2.85
# epoch 117: L_tot 2776.50 L_likelihood 2773.10 L_divergence 3.40
# epoch 118: L_tot 2778.61 L_likelihood 2775.48 L_divergence 3.13
# epoch 119: L_tot 2794.14 L_likelihood 2791.22 L_divergence 2.92
# epoch 120: L_tot 2794.04 L_likelihood 2790.66 L_divergence 3.38
# epoch 121: L_tot 2798.49 L_likelihood 2795.46 L_divergence 3.03
# epoch 122: L_tot 2796.61 L_likelihood 2793.27 L_divergence 3.34
# epoch 123: L_tot 2755.94 L_likelihood 2753.11 L_divergence 2.83
# epoch 124: L_tot 2785.23 L_likelihood 2782.20 L_divergence 3.03
# epoch 125: L_tot 2780.90 L_likelihood 2777.78 L_divergence 3.12
# epoch 126: L_tot 2784.42 L_likelihood 2781.63 L_divergence 2.79
# epoch 127: L_tot 2790.15 L_likelihood 2786.56 L_divergence 3.59
# epoch 128: L_tot 2814.83 L_likelihood 2811.42 L_divergence 3.41
# epoch 129: L_tot 2780.55 L_likelihood 2777.44 L_divergence 3.10
# epoch 130: L_tot 2782.25 L_likelihood 2779.16 L_divergence 3.09
# epoch 131: L_tot 2803.35 L_likelihood 2800.13 L_divergence 3.22
# epoch 132: L_tot 2783.79 L_likelihood 2780.66 L_divergence 3.13
# epoch 133: L_tot 2763.56 L_likelihood 2760.27 L_divergence 3.29
# epoch 134: L_tot 2794.17 L_likelihood 2791.10 L_divergence 3.06
# epoch 135: L_tot 2789.85 L_likelihood 2786.44 L_divergence 3.42
# epoch 136: L_tot 2762.79 L_likelihood 2759.49 L_divergence 3.30
# epoch 137: L_tot 2811.12 L_likelihood 2807.56 L_divergence 3.56
# epoch 138: L_tot 2782.74 L_likelihood 2779.78 L_divergence 2.96
# epoch 139: L_tot 2777.58 L_likelihood 2774.61 L_divergence 2.97
# epoch 140: L_tot 2795.38 L_likelihood 2791.78 L_divergence 3.60
# epoch 141: L_tot 2760.21 L_likelihood 2757.12 L_divergence 3.09
# epoch 142: L_tot 2780.80 L_likelihood 2777.77 L_divergence 3.03
# epoch 143: L_tot 2781.30 L_likelihood 2777.42 L_divergence 3.87
# epoch 144: L_tot 2781.35 L_likelihood 2777.60 L_divergence 3.75
# epoch 145: L_tot 2801.94 L_likelihood 2799.09 L_divergence 2.85
# epoch 146: L_tot 2776.97 L_likelihood 2774.02 L_divergence 2.95
# epoch 147: L_tot 2764.12 L_likelihood 2761.41 L_divergence 2.71
# epoch 148: L_tot 2773.28 L_likelihood 2769.77 L_divergence 3.51
# epoch 149: L_tot 2769.95 L_likelihood 2767.13 L_divergence 2.82
# epoch 150: L_tot 2796.50 L_likelihood 2793.49 L_divergence 3.02
# epoch 151: L_tot 2801.18 L_likelihood 2798.40 L_divergence 2.78
# epoch 152: L_tot 2793.59 L_likelihood 2790.36 L_divergence 3.23
# epoch 153: L_tot 2778.98 L_likelihood 2775.40 L_divergence 3.58
# epoch 154: L_tot 2765.03 L_likelihood 2761.68 L_divergence 3.35
# epoch 155: L_tot 2770.55 L_likelihood 2766.87 L_divergence 3.68
# epoch 156: L_tot 2801.69 L_likelihood 2798.57 L_divergence 3.12
# epoch 157: L_tot 2785.22 L_likelihood 2782.03 L_divergence 3.19
# epoch 158: L_tot 2776.12 L_likelihood 2772.92 L_divergence 3.21
# epoch 159: L_tot 2791.95 L_likelihood 2788.74 L_divergence 3.21
# epoch 160: L_tot 2751.19 L_likelihood 2748.02 L_divergence 3.17
# epoch 161: L_tot 2809.30 L_likelihood 2806.20 L_divergence 3.10
# epoch 162: L_tot 2813.56 L_likelihood 2810.98 L_divergence 2.58
# epoch 163: L_tot 2781.42 L_likelihood 2778.94 L_divergence 2.48
# epoch 164: L_tot 2778.73 L_likelihood 2775.51 L_divergence 3.23
# epoch 165: L_tot 2777.93 L_likelihood 2774.86 L_divergence 3.07
# epoch 166: L_tot 2758.14 L_likelihood 2754.63 L_divergence 3.51
# epoch 167: L_tot 2777.62 L_likelihood 2774.05 L_divergence 3.57
# epoch 168: L_tot 2762.47 L_likelihood 2759.17 L_divergence 3.30
# epoch 169: L_tot 2816.51 L_likelihood 2813.19 L_divergence 3.32
# epoch 170: L_tot 2808.25 L_likelihood 2805.22 L_divergence 3.03
# epoch 171: L_tot 2799.05 L_likelihood 2795.02 L_divergence 4.03
# epoch 172: L_tot 2800.04 L_likelihood 2796.43 L_divergence 3.61
# epoch 173: L_tot 2805.02 L_likelihood 2802.08 L_divergence 2.94
# epoch 174: L_tot 2793.30 L_likelihood 2790.06 L_divergence 3.25
# epoch 175: L_tot 2784.43 L_likelihood 2781.39 L_divergence 3.04
# epoch 176: L_tot 2775.56 L_likelihood 2772.33 L_divergence 3.22
# epoch 177: L_tot 2800.98 L_likelihood 2797.99 L_divergence 2.99
# epoch 178: L_tot 2807.93 L_likelihood 2804.64 L_divergence 3.30
# epoch 179: L_tot 2782.36 L_likelihood 2778.98 L_divergence 3.38
# epoch 180: L_tot 2774.40 L_likelihood 2771.07 L_divergence 3.33
# epoch 181: L_tot 2770.54 L_likelihood 2767.01 L_divergence 3.54
# epoch 182: L_tot 2777.59 L_likelihood 2774.32 L_divergence 3.27
# epoch 183: L_tot 2789.26 L_likelihood 2785.75 L_divergence 3.51
# epoch 184: L_tot 2801.92 L_likelihood 2798.65 L_divergence 3.27
# epoch 185: L_tot 2779.30 L_likelihood 2776.17 L_divergence 3.12
# epoch 186: L_tot 2772.41 L_likelihood 2768.84 L_divergence 3.57
# epoch 187: L_tot 2792.86 L_likelihood 2789.30 L_divergence 3.56
# epoch 188: L_tot 2768.59 L_likelihood 2765.65 L_divergence 2.94
# epoch 189: L_tot 2783.78 L_likelihood 2780.47 L_divergence 3.32
# epoch 190: L_tot 2813.91 L_likelihood 2810.35 L_divergence 3.56
# epoch 191: L_tot 2770.63 L_likelihood 2767.22 L_divergence 3.42
# epoch 192: L_tot 2800.48 L_likelihood 2797.05 L_divergence 3.43
# epoch 193: L_tot 2800.36 L_likelihood 2797.43 L_divergence 2.93
# epoch 194: L_tot 2757.62 L_likelihood 2754.71 L_divergence 2.91
# epoch 195: L_tot 2755.41 L_likelihood 2752.01 L_divergence 3.41
# epoch 196: L_tot 2787.83 L_likelihood 2784.90 L_divergence 2.92
# epoch 197: L_tot 2768.13 L_likelihood 2764.69 L_divergence 3.44
# epoch 198: L_tot 2771.58 L_likelihood 2768.14 L_divergence 3.44
# epoch 199: L_tot 2820.32 L_likelihood 2817.06 L_divergence 3.26

# %%
import matplotlib.pyplot as plt
def save_scattered_image(z, id, name='scattered_image.jpg'):
    N = 4
    z_range = 3
    plt.figure(figsize=(8, 6))
    plt.scatter(z[:, 0], z[:, 1], c=np.argmax(id, 1), marker='o', edgecolor='none', cmap=discrete_cmap(N, 'jet'))
    plt.colorbar(ticks=range(N))
    axes = plt.gca()
    axes.set_xlim([-z_range-2, z_range+2])
    axes.set_ylim([-z_range-2, z_range+2])
    plt.grid(True)
    plt.savefig("./results/time/" + name)


def discrete_cmap(N, base_cmap=None):

    base = plt.cm.get_cmap(base_cmap)
    color_list = base(np.linspace(0, 1, N))
    cmap_name = base.name + str(N)
    return base.from_list(cmap_name, color_list, N)

# %%
with tf.Session() as sess:
    learning_rate= 0.0005
    dense_layers = [1500,700,300]
    dense_funcs = ['elu','elu','tanh']
    dim_z = 2#20 # latent vector size
    dim_out = np_train.shape[1]
    
    
    autoencoder = vae(sess,learning_rate,dense_layers,dense_funcs,dim_z,dim_out)
    autoencoder.load()
    
    sess.run(tf.global_variables_initializer(), feed_dict={autoencoder.keep_prob : 0.9})
    
    PMLR = True
    ADD_NOISE = True
    if PMLR and dim_z == 2:
        
        # Plot for manifold learning result
#         PMLR = plot_utils.Plot_Manifold_Learning_Result('./results/time', PMLR_n_img_x, PMLR_n_img_y, IMAGE_SIZE_MNIST, IMAGE_SIZE_MNIST, PMLR_resize_factor, PMLR_z_range)

        x_PMLR = np_train
        id_PMLR = df_train['id'].values
        nb_classes = 4
        targets = id_PMLR
        one_hot_targets = np.eye(nb_classes)[targets]
#         x_PMLR = np_new
        
        if ADD_NOISE:
            x_PMLR = x_PMLR * np.random.randint(2, size=x_PMLR.shape)
            x_PMLR += np.random.randint(2, size=x_PMLR.shape)

        z_PMLR = sess.run(autoencoder.z, feed_dict={autoencoder.x_hat: x_PMLR, autoencoder.keep_prob : 1})
        save_scattered_image(z_PMLR,one_hot_targets, name="/PMLR_map_stock.jpg")
# Out:
# encoder_dense_layers [1500, 700, 300, 2]
# gaussian encoder mean:(?, 2)
# mu:(?, 2) sigma:(?, 2)
# encoder output z:(?, 2)
# decoder_dense_layers [300, 700, 1500, 4323]
# decoder output y:(?, 4323)
# INFO:tensorflow:Restoring parameters from ./model/vae.model-1
#  [*] Success to read vae.model-1
